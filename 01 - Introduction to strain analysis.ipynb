# %% [markdown]
# # Homogeneous deformation

# %% [markdown]
# Often described as deformation during which lines remain as lines and parallel lines remain parallel. Homogeneous deformation could be described as **affine transformation** of initial coordinates

# %% [markdown]
# \begin{align*}x &= aX+bY+t_X \\ y &= cX+dY+t_Y \end{align*}

# %% [markdown]
# or in matrix form using homogeneous coordinates:

# %% [markdown]
# $$ \begin{bmatrix} x \\ y \\ 1 \end{bmatrix}=\begin{bmatrix} a & b & t_X \\ c & d & t_Y \\ 0 & 0 & 1 \end{bmatrix}\begin{bmatrix}X \\ Y \\ 1 \end{bmatrix}$$

# %% [markdown]
# **Properties of homogeneous deformation are not spatially dependent**

# %% [markdown]
# ## Deformation gradient

# %% [markdown]
# Without translation the homogeneous deformation (rotation and strain) could be described as:

# %% [markdown]
# \begin{align*}x &= aX+bY \\ y &= cX+dY \end{align*}

# %% [markdown]
# $$ \begin{bmatrix}x \\ y\end{bmatrix}=\begin{bmatrix} a & b \\ c & d \end{bmatrix}\begin{bmatrix}X \\ Y\end{bmatrix}$$

# %% [markdown]
# or im matrix form

# %% [markdown]
# $$x=\boldsymbol{F}X$$

# %% [markdown]
# where $ \mathbf{F} $ is so called **deformation gradient**.

# %% [markdown]
# Note, that as we excluded translation, the origin of coordinates do not change during deformation:

# %% [markdown]
# $$ \begin{bmatrix} 0 \\ 0  \end{bmatrix}=\boldsymbol{F}\begin{bmatrix} 0 \\ 0  \end{bmatrix} $$

# %% [markdown]
# ## Displacement gradient

# %% [markdown]
# Displacement of particle is vector between initial and final postion, i.e:

# %% [markdown]
# \begin{align*}u &= x-X = aX+bY-X = (a-1)X+bY\\ v &= y-Y = cX+dY-Y = cX+(d-1)Y\end{align*}

# %% [markdown]
# $$ \begin{bmatrix}u \\ v\end{bmatrix}=\begin{bmatrix} a-1 & b \\ c & d-1 \end{bmatrix}\begin{bmatrix}X \\ Y\end{bmatrix}$$

# %% [markdown]
# or

# %% [markdown]
# $$u=(\boldsymbol{F}-\boldsymbol{I})X=\boldsymbol{\nabla}\mathbf{u}X$$

# %% [markdown]
# where $ \boldsymbol{\nabla}\mathbf{u} $ is so called **displacement gradient**.

# %% [markdown]
# What do you think corresponds to symmetric $  \cfrac{1}{2}(\boldsymbol{\nabla}\mathbf{u} + \boldsymbol{\nabla}\mathbf{u}^T) $ and antisymmetric $ \cfrac{1}{2}(\boldsymbol{\nabla}\mathbf{u} - \boldsymbol{\nabla}\mathbf{u}^T) $ part of the displacement gradient matrix?

# %% [markdown]
# ## Let's Python it

# %%
# %matplotlib inline

# %% [markdown]
# Lets try to visualize how unit circle deforms during homogeneous deformation:

# %%
from pylab import *

# parametric definition of unit circle
theta = linspace(0,2*pi,300)
X = cos(theta)
Y = sin(theta)
plot(X, Y)
axis('equal')

# Apply deformation gradient
F = array([[2,0],[0,0.5]])
x,y = dot(F, [X,Y])
plot(x,y)

# %% [markdown]
# To visualize displacement field we have to calculate displacement for points on regular grid and plot it using command `quiver`.

# %%
# create rectangular grid
xgrid = linspace(-2.2,2.2,21)
ygrid = linspace(-1.9,1.9,17)
X,Y = meshgrid(xgrid, ygrid)

# calculate displacements
J = F - eye(2)
u = J[0,0]*X + J[0,1]*Y
v = J[1,0]*X + J[1,1]*Y

# plot
quiver(X,Y,u,v, angles='xy')
axis('equal')
# Out:
# (-3.0, 3.0, -2.0, 2.0)

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./css/ipython_custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro";
# 			font-size: 90%;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
